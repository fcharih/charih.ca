# %% [markdown]
# # Exercise 3
#
# In this exercise, we are pretending that we are biostatisticians evaluating a clinical trial for 2 drugs that target a disease that affects the elderly.
#
# The trial is, of course, placebo-controlled.

# %%
# To use pandas, you must first import it
# Note: by convention, we import pandas as pd
import pandas as pd
import numpy as np

# %% [markdown]
# ## Task 1 - Import the datasets
#
# We saw how to import a csv/tsv file. Make sure that the file exercise3.tsv is uploaded and import it into this Jupyter environment.

# %%
# Import the trial data (exercise3_data.csv)
df1 = # CODE GOES HERE

# %%
# Import the trial data (exercise3_patients.tsv)
df2 = # CODE GOES HERE

# %% [markdown]
# Create a new dataframe (df) that contains the correct age, email and city of the participants. There is a correspondance by participant id.
#
# **NOTE: Normally, one would never do this unless required, due to security and ethics concerns**

# %%
df = # CODE GOES HERE

# %% [markdown]
# ## Task 2 - Counting...
#
# Participants are assigned to a treatment randomly by a pseudo-random computer algorithm.
#
# How many patients are in the disease and control groups?

# %%
# CODE GOES HERE
# Out:
# disease    517
# control    483
# Name: group, dtype: int64

# %% [markdown]
# How many patients receive the placebo, treatment 1 and treatment 2.

# %%
# CODE GOES HERE
# Out:
# treatment1    355
# treatment2    326
# placebo       319
# Name: treatment, dtype: int64

# %% [markdown]
# What is the split for the 6 groups?

# %%
# CODE GOES HERE
# Out:
# group    treatment
# control  treatment1    186
#          treatment2    152
#          placebo       145
# disease  placebo       174
#          treatment2    174
#          treatment1    169
# Name: treatment, dtype: int64

# %% [markdown]
# ## Task 3 - Comparing groups
#
# What is the mean survival of the participants in the disease and control group?

# %%
# CODE GOES HERE
# Out:
# group
# control    120.241079
# disease     21.078013
# Name: survival, dtype: float64

# %% [markdown]
# ## Task 4 - Comparing treatments
#
# What is the median survival of survival of participants in the disease group for the three treatments?

# %%
# CODE GOES HERE
# Out:
# group    treatment
# control  placebo       120.989376
#          treatment1    120.294125
#          treatment2    119.774810
# disease  placebo        12.120471
#          treatment1     14.412090
#          treatment2     37.343942
# Name: survival, dtype: float64

# %% [markdown]
# ## Task 5 - Plotting a bar chart
#
# Plot a bar chart showing the median survival of the 6 different groups.

# %%
# CODE GOES HERE
