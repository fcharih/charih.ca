# %% [markdown]
# # Exercise 1
#
# In this exercise, we are looking at *Series*, the most fundamental Pandas data structure. We will be looking at fasting blood sugar levels to try and identify pre-diabetic and diabetic patients in simulated data.

# %%
# To use pandas, you must first import it
# Note: by convention, we import pandas as pd
import pandas as pd
import numpy as np

# %% [markdown]
# We can create some synthetic data.

# %%
# Boy names taken off the interwebz
patient_names = [line.rstrip("\n") for line in open("exercise1.txt")]

# Create random sugar levels
np.random.seed(42)
sugar_levels = np.random.normal(loc=85, scale=30, size=len(patient_names))

# Replace 5 random values with NaNs
nan_indices = np.random.randint(0, len(patient_names), 5)
sugar_levels[nan_indices] = np.nan

# %% [markdown]
# ## Task 1 - Create the series with the patient names as indices.
#
# **Hint:** the function Series has a keyword argument names index (i.e. pd.Series(data, index=...))

# %%
# Create the series
series = # ANSWER GOES HERE

# %% [markdown]
# ## Task 2 -  Find the number of patients that have pre-diabetes and diabetes
#
# The Mayo Clinic considers fasting sugar levels <100 mg/dL to be healthy, 100-125 mg/dL to be prediabetes and levels >125 mg/dL to be diabetes.

# %%
# Number of patients with pre-diabetes
num_prediabetic_patients = # ANSWER GOES HERE

print("There are {} pre-diabetic patients.".format(num_prediabetic_patients))
# Out:
# 5

# %%
# Number of patients with diabetes
num_prediabetic_patients = # ANSWER GOES HERE

print("There are {} diabetic patients.".format(num_diabetic_patients))
# Out:
# 4

# %% [markdown]
# ## Task 3 - Identify the 5 patients with the highest fasting sugar levels
#
# These patients will require an intervention!

# %%
# Top 5 patients are (just type in the expression without assignment ("=") that returns the 5 largest FBS levels; no need to print)
# ANSWER GOES HERE
# Out:
# Grayson    140.568346
# Elijah     132.376384
# James      130.690896
# Samuel     128.969463
# Nathan     116.713667
# dtype: float64

# %% [markdown]
# ## Task 4 - Identify the 5 patients for whom a value is missing
#
# These patients will need to come in for a blood draw.

# %%
# Patients with missing values
series[series.isna()]
# Out:
# Liam     NaN
# Daniel   NaN
# Luke     NaN
# Joshua   NaN
# Caleb    NaN
# dtype: float64

# %% [markdown]
# ## Task 5 - Compute the z-score of every patient's FBS
#
# Compute the Z-score of every patient's sugar level. The z-score is computed by subtracting the mean to the score and dividing by the standard deviation:
#
# $$z = \frac{x - \bar{x}}{\sigma}$$
#
# *This should not take more than a line of code.*

# %%
# Compute the z-scores
# ANSWER GOES HERE
# Out:
# Liam                NaN
# Noah           0.059960
# William        0.914056
# James          1.865292
# Oliver        -0.044243
# Benjamin      -0.044226
# Elijah         1.926346
# Lucas          1.044185
# Mason         -0.299967
# Logan          0.799813
# Alexander     -0.293386
# Ethan         -0.295898
# Jacob          0.473153
# Michael       -1.868955
# Daniel              NaN
# Henry         -0.400828
# Jackson       -0.890435
# Sebastian      0.551705
# Aiden         -0.776540
# Matthew       -1.324542
# Samuel         1.802936
# David         -0.035140
# Joseph         0.283595
# Carter        -1.338066
# Owen          -0.381370
# Wyatt          0.330752
# John          -1.040576
# Jack           0.618484
# Luke                NaN
# Jayden        -0.106773
# Dylan         -0.443664
# Grayson        2.223087
# Levi           0.195544
# Isaac         -0.939206
# Gabriel        1.104073
# Julian        -1.116482
# Mateo          0.437184
# Anthony       -1.919367
# ...
