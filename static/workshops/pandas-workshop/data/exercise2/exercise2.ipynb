# %% [markdown]
# # Exercise 2
#
# In this exercise, we are toying around with *dataframe*. The most useful data structure in Pandas.
#
# Let's imagine that we are psychologists interested in understanding the prevalence of anxiety in Ottawa. We designed a questionnaire and collected 9,905 responses.
#
# We are looking to answer a couple of questions.

# %%
# To use pandas, you must first import it
# Note: by convention, we import pandas as pd
import pandas as pd
import numpy as np

# %% [markdown]
# ## Task 1 - Import the dataset
#
# We saw how to import a csv/tsv file. Make sure that the file exercise2.csv is uploaded and import it into this Jupyter environment.

# %%
df = # CODE GOES HERE

# %% [markdown]
# ## Task 2 - Basic cleaning
#
# Many participants submitted the web form twice by clicking on the submit button more than once (boo!).
#
# How many unique patients filled ou the questionnaire?

# %%
# Number of unique patients that filled out the questionnaire

# CODE GOES HERE

# %% [markdown]
# How many responses are duplicates?

# %%
# Number of duplicated rows

# CODE GOES HERE

# %% [markdown]
# Drop the duplicated rows to keep only one response per participant.

# %%
# Drop the duplicated rows
df = # CODE GOES HERE

# %% [markdown]
# ## Task 3 - Count the incomplete answers
#
# Certain participants failed to answer certain questions, and this was not caught, because you were using a poorly built questionnaire software.
#
# How many participants failed to fully complete the questionnaire (i.e. have null values)?

# %%
# Count the number of incomplete answers

# CODE GOES HERE

# %% [markdown]
# ## Task 4 - Identify the most common form of anxiety
#
# What is the most common form of anxiety?

# %%
# Most common form of anxiety
# ANSWER GOES HERE
# Out:
# 5

# %% [markdown]
# ## Task 5 - Generate a total anxiety score (TAS)
#
# You have developed a new metric to evaluate the overall degree of anxiety which is simply the sum of the individual anxiety scores:
#
# $$TAS = S_{OCD} + S_{panic} + S_{social\ anxiety}$$
#
# Add a column to the dataframe that contains the TAS score.

# %%
# ANSWER GOES HERE (you can replace the old dataframe or create a new one)
# Out:
# 4

# %% [markdown]
# What is the mean TAS score?

# %%
# Compute the mean TAS score

mean_tas_score = # ANSWER GOES HERE
print("The mean TAS score is {}.".format(mean_tas_score))

# %% [markdown]
# ## Task 6 - Create a column that maps the age to a label
#
# We want a column that indicates the category of participant: "adult", "teenager" or "child".
#
# $$Age_{child} \in [12, 13)$$
# $$Age_{teenager} \in [13,18)$$
# $$Age_{adult} \in [18,\infty)$$

# %%
# ANSWER GOES HERE (you can replace the old dataframe or create a new one) -- this answer needs a bit more than a single line of code.

# %% [markdown]
# ## Task 7 - Find the count of participants the different categories
#
# How many children, teenagers and adults are there? (There is a function that allows you to find this: see slide 14).

# %%
# ANSWER GOES HERE

# %% [markdown]
# ## Task 8 - Find Pearson's correlation coefficient $r$ between the total anxiety score and the age
#
# You suspect there might be a correlation between the age of the participant and the TAS. Find Pearson's $r$ between these two variables.

# %%
# ANSWER GOES HERE
